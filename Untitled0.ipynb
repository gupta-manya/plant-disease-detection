# %% [markdown]
# <a href="https://colab.research.google.com/github/gupta-manya/plant-detecton/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
print("TensorFlow version:", tf.__version__)
print("GPU Available:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow version: 2.18.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !pip install tensorflow

# %%
# !pip install numpy pandas matplotlib opencv-python

# %%
# !nvidia-smi
# Out:
# Sat Feb  8 13:32:38 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8             12W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !wget https://developer.download.nvidia.com/compute/cuda/11.8.0/local_installers/cuda_11.8.0_522.06_windows.exe
# !apt-get install libcudnn8=8.8.0.*-1+cuda11.8
# Out:
# --2025-02-08 13:32:38--  https://developer.download.nvidia.com/compute/cuda/11.8.0/local_installers/cuda_11.8.0_522.06_windows.exe
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 23.60.173.16, 23.60.173.59
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|23.60.173.16|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3211785216 (3.0G) [application/octet-stream]
# Saving to: ‘cuda_11.8.0_522.06_windows.exe’
#
# cuda_11.8.0_522.06_ 100%[===================>]   2.99G   110MB/s    in 30s
#
# 2025-02-08 13:33:09 (103 MB/s) - ‘cuda_11.8.0_522.06_windows.exe’ saved [3211785216/3211785216]
#
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Selected version '8.8.0.121-1+cuda11.8' (NVIDIA CUDA:developer.download.nvidia.com [amd64]) for 'libcudnn8'
# The following NEW packages will be installed:
#   libcudnn8
# ...

# %%
# !apt-get install cuda-11-2 libcudnn8=8.1.0.*-1+cuda11.2
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package libcudnn8 is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
#
# E: Unable to locate package cuda-11-2
# E: Version '8.1.0.*-1+cuda11.2' for 'libcudnn8' was not found

# %%
# !nvcc --version
# !nvidia-smi
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2024 NVIDIA Corporation
# Built on Thu_Jun__6_02:18:23_PDT_2024
# Cuda compilation tools, release 12.5, V12.5.82
# Build cuda_12.5.r12.5/compiler.34385749_0
# Sat Feb  8 13:34:18 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# ...

# %%
# !pip install nvidia-pyindex
# !pip install nvidia-cuda-runtime-cu11
# !pip install nvidia-cublas-cu11
# !pip install nvidia-cudnn-cu11
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for nvidia-pyindex: filename=nvidia_pyindex-1.0.9-py3-none-any.whl size=8419 sha256=b8d1ba30285ba54d3eeecb2995bfbc8f6fd5dccc066dc88aca19763d35d4be5b
#   Stored in directory: /root/.cache/pip/wheels/49/d0/7d/b68b3665d16ee20355e65fb7ef48b7ca26533217d9f09924fe
# Successfully built nvidia-pyindex
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 520.9/520.9 MB 3.5 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install gdown

# %%
# !gdown --id 1_5G3Cz0WQtZeTxzsq5lrTUfEnNy78WeY -O dataset.zip
# Out:
# /usr/local/lib/python3.11/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1_5G3Cz0WQtZeTxzsq5lrTUfEnNy78WeY
# From (redirected): https://drive.google.com/uc?id=1_5G3Cz0WQtZeTxzsq5lrTUfEnNy78WeY&confirm=t&uuid=87961078-5907-4d08-b47c-6ca892ef240e
# To: /content/dataset.zip
# 100% 1.49G/1.49G [00:48<00:00, 30.5MB/s]

# %%
import zipfile

with zipfile.ZipFile("dataset.zip", 'r') as zip_ref:
    zip_ref.extractall("dataset")  # Extracts into 'dataset' folder

# %%
import os
print(os.listdir("dataset"))
# Out:
# ['__MACOSX', 'Plant_Disease_Dataset']

# %%
train_dir = "dataset/train"
valid_dir = "dataset/valid"
test_dir = "dataset/test"

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
import matplotlib.pyplot as plt

# %%
dataset_path = "dataset"  # The folder where your dataset is extracted
print(os.listdir(dataset_path))
# Out:
# ['__MACOSX', 'Plant_Disease_Dataset']

# %%
import os

dataset_path = "dataset/Plant_Disease_Dataset"  # Corrected path
print(os.listdir(dataset_path))  # Check if it contains 'train', 'valid', 'test'
# Out:
# ['valid', 'test', 'train', '.DS_Store']

# %%
train_dir = os.path.join(dataset_path, "train")
valid_dir = os.path.join(dataset_path, "valid")
test_dir = os.path.join(dataset_path, "test")

# %%
train_datagen = ImageDataGenerator(
    rescale=1.0/255,  # Normalize pixel values
    rotation_range=30,  # Augment by rotating images
    width_shift_range=0.2,  # Shift images left/right
    height_shift_range=0.2,  # Shift images up/down
    shear_range=0.2,  # Shear transformation
    zoom_range=0.2,  # Random zoom
    horizontal_flip=True,  # Flip images
    fill_mode="nearest"
)

valid_datagen = ImageDataGenerator(rescale=1.0/255)
test_datagen = ImageDataGenerator(rescale=1.0/255)

# %%
batch_size = 32  # You can change this depending on memory availability
image_size = (150, 150)  # Resize images to 150x150 pixels

train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical'  # Use 'binary' for 2 classes
)

valid_generator = valid_datagen.flow_from_directory(
    valid_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=image_size,
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 70295 images belonging to 38 classes.
# Found 17572 images belonging to 38 classes.
# Found 33 images belonging to 1 classes.

# %%
x, y = next(train_generator)  # Correct way in Python 3
plt.imshow(x[0])
plt.show()

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input(shape=(150, 150, 3)),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),

    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(len(train_generator.class_indices), activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    epochs=20,  # Adjust as needed
    validation_data=valid_generator
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/20
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 485s 217ms/step - accuracy: 0.3232 - loss: 2.3966 - val_accuracy: 0.7042 - val_loss: 0.9799
# Epoch 2/20
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 464s 211ms/step - accuracy: 0.7102 - loss: 0.9342 - val_accuracy: 0.8177 - val_loss: 0.5679
# Epoch 3/20
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 461s 210ms/step - accuracy: 0.7817 - loss: 0.6927 - val_accuracy: 0.8520 - val_loss: 0.4627
# Epoch 4/20
# 2197/2197 ━━━━━━━━━━━━━━━━━━━━ 465s 212ms/step - accuracy: 0.8232 - loss: 0.5568 - val_accuracy: 0.8805 - val_loss: 0.3816
# Epoch 5/20
# ...
